# %%
import pandas as pd

# %%
data = pd.read_csv('data/EC10.csv')

# %%
data.head()
# Out:
#       id                                               text  \
# 0  32934  Zoe's Kitchen, Inc. (NYSE:ZOES)\nQ2 2015 Earni...
# 1  32905  Autodesk, Inc. (NASDAQ:ADSK)\nQ2 2016 Earnings...
# 2  32926  Smith & Wesson Holding Corp. (NASDAQ:SWHC)\nQ1...
# 3  32930  Ulta Salon, Cosmetics & Fragrance, Inc. (NASDA...
# 4  32907  Splunk Inc. (NASDAQ:SPLK)\nQ2 2016 Earnings Co...
#
#                   date                                  company  \
# 0  2015-08-28 00:11:00                      Zoe's Kitchen, Inc.
# 1  2015-08-28 00:07:00                           Autodesk, Inc.
# 2  2015-08-27 23:25:00       Smith & Wesson Holding Corporation
# 3  2015-08-27 23:09:00  Ulta Salon, Cosmetics & Fragrance, Inc.
# 4  2015-08-27 22:56:00                              Splunk Inc.
#
#               sector
# 0  Consumer Services
# 1         Technology
# 2      Capital Goods
# 3  Consumer Services
# 4         Technology

# %% [markdown]
# 1- create a col length that contains the length of text

# %%
data['length'] = data['text'].str.len()
data.head()
# Out:
#       id                                               text  \
# 0  32934  Zoe's Kitchen, Inc. (NYSE:ZOES)\nQ2 2015 Earni...
# 1  32905  Autodesk, Inc. (NASDAQ:ADSK)\nQ2 2016 Earnings...
# 2  32926  Smith & Wesson Holding Corp. (NASDAQ:SWHC)\nQ1...
# 3  32930  Ulta Salon, Cosmetics & Fragrance, Inc. (NASDA...
# 4  32907  Splunk Inc. (NASDAQ:SPLK)\nQ2 2016 Earnings Co...
#
#                   date                                  company  \
# 0  2015-08-28 00:11:00                      Zoe's Kitchen, Inc.
# 1  2015-08-28 00:07:00                           Autodesk, Inc.
# 2  2015-08-27 23:25:00       Smith & Wesson Holding Corporation
# 3  2015-08-27 23:09:00  Ulta Salon, Cosmetics & Fragrance, Inc.
# 4  2015-08-27 22:56:00                              Splunk Inc.
#
#               sector  length
# 0  Consumer Services   43945
# 1         Technology   64820
# 2      Capital Goods   41111
# 3  Consumer Services   65628
# 4         Technology   61677

# %% [markdown]
# 2- create a col words that contains the number of words in text

# %%
data['words'] = data['text'].str.split().str.len()
data.head()
# Out:
#       id                                               text  \
# 0  32934  Zoe's Kitchen, Inc. (NYSE:ZOES)\nQ2 2015 Earni...
# 1  32905  Autodesk, Inc. (NASDAQ:ADSK)\nQ2 2016 Earnings...
# 2  32926  Smith & Wesson Holding Corp. (NASDAQ:SWHC)\nQ1...
# 3  32930  Ulta Salon, Cosmetics & Fragrance, Inc. (NASDA...
# 4  32907  Splunk Inc. (NASDAQ:SPLK)\nQ2 2016 Earnings Co...
#
#                   date                                  company  \
# 0  2015-08-28 00:11:00                      Zoe's Kitchen, Inc.
# 1  2015-08-28 00:07:00                           Autodesk, Inc.
# 2  2015-08-27 23:25:00       Smith & Wesson Holding Corporation
# 3  2015-08-27 23:09:00  Ulta Salon, Cosmetics & Fragrance, Inc.
# 4  2015-08-27 22:56:00                              Splunk Inc.
#
#               sector  length  words
# 0  Consumer Services   43945   7690
# 1         Technology   64820  11259
# 2      Capital Goods   41111   7015
# 3  Consumer Services   65628  11173
# ...

# %% [markdown]
# 3- extract tickers and stock markets from text

# %%
data['text'].str.extract("([A-Z]+):([A-Z]+)")
# Out:
#         0     1
# 0    NYSE  ZOES
# 1  NASDAQ  ADSK
# 2  NASDAQ  SWHC
# 3  NASDAQ  ULTA
# 4  NASDAQ  SPLK
# 5    NYSE   GME
# 6  NASDAQ  OVTI
# 7    NYSE    TD
# 8  NASDAQ  BAMM
# 9    NYSE  VEEV
