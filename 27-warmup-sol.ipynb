# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# %% [markdown]
# Obtain data about [US 116th congress members](http://clerk.house.gov/xml/lists/MemberData.xml), what is the percentage of R, D and independents in each state?

# %%
response = requests.get("http://clerk.house.gov/xml/lists/MemberData.xml")
if response:
    data = response.text

# %%
xml = ET.fromstring(data)

# %%
res = []
for member in xml.findall("./members/member/member-info"):
    party = member.find("party")
    state = member.find("state/state-fullname")
    res.append({"state":state.text, "party":party.text})

# %%
# or using a list comprehension
res = [{"party":member.find("party").text, "state":member.find("state/state-fullname").text}
      for member in xml.findall("./members/member/member-info")]

# %%
df = pd.DataFrame(res)

# %%
df = df.fillna("I") #replace None for independent
df['count'] = 1

# %%
df.groupby(["state", "party"]).count().unstack("party").fillna(0)
# Out:
#                          count
# party                        D    I     R
# state
# Alabama                    1.0  0.0   6.0
# Alaska                     0.0  0.0   1.0
# American Samoa             0.0  0.0   1.0
# Arizona                    5.0  0.0   4.0
# Arkansas                   0.0  0.0   4.0
# California                46.0  0.0   7.0
# Colorado                   4.0  0.0   3.0
# Connecticut                5.0  0.0   0.0
# Delaware                   1.0  0.0   0.0
# District of Columbia       1.0  0.0   0.0
# Florida                   13.0  0.0  14.0
# Georgia                    5.0  0.0   9.0
# Guam                       1.0  0.0   0.0
# Hawaii                     2.0  0.0   0.0
# Idaho                      0.0  0.0   2.0
# Illinois                  13.0  0.0   5.0
# Indiana                    2.0  0.0   7.0
# Iowa                       3.0  0.0   1.0
# Kansas                     1.0  0.0   3.0
# Kentucky                   1.0  0.0   5.0
# Louisiana                  1.0  0.0   5.0
# Maine                      2.0  0.0   0.0
# Maryland                   7.0  0.0   1.0
# Massachusetts              9.0  0.0   0.0
# Michigan                   7.0  1.0   6.0
# Minnesota                  5.0  0.0   3.0
# Mississippi                1.0  0.0   3.0
# Missouri                   2.0  0.0   6.0
# Montana                    0.0  0.0   1.0
# Nebraska                   0.0  0.0   3.0
# Nevada                     3.0  0.0   1.0
# New Hampshire              2.0  0.0   0.0
# New Jersey                11.0  0.0   1.0
# New Mexico                 3.0  0.0   0.0
# New York                  21.0  1.0   5.0
# North Carolina             3.0  0.0  10.0
# North Dakota               0.0  0.0   1.0
# Northern Mariana Islands   1.0  0.0   0.0
# Ohio                       4.0  0.0  12.0
# Oklahoma                   1.0  0.0   4.0
# Oregon                     4.0  0.0   1.0
# Pennsylvania               9.0  0.0   9.0
# Puerto Rico                0.0  0.0   1.0
# Rhode Island               2.0  0.0   0.0
# South Carolina             2.0  0.0   5.0
# South Dakota               0.0  0.0   1.0
# Tennessee                  2.0  0.0   7.0
# Texas                     13.0  0.0  23.0
# Utah                       1.0  0.0   3.0
# Vermont                    1.0  0.0   0.0
# Virgin Islands             1.0  0.0   0.0
# Virginia                   7.0  0.0   4.0
# Washington                 7.0  0.0   3.0
# West Virginia              0.0  0.0   3.0
# Wisconsin                  3.0  1.0   4.0
# Wyoming                    0.0  0.0   1.0
