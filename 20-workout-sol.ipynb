# %%
import pandas as pd

# %% [markdown]
# The data frames `Customers`, `Employees`, `Offices`, `OrderDetails`, `Orders`, `Payments`, `ProductLines`, and `Products` contain data of the corresponding tables in the [ClassicModels database](https://www.richardtwatson.com/dm6e/Reader/ClassicModels.html).
#
# The entity relationship diagram is shown here ![ERD](figures/ClassicModels.png)

# %% [markdown]
# Using Pandas merge and join operations, answer the following questions:
#
# *Text queries*
#
# - Find products containing the name 'Ford'.
# - List products ending in 'ship'.
# - Report the number of customers in Denmark, Norway, and Sweden.
# - What are the products with a product code in the range S700_1000 to S700_1499?
# - Which customers have a digit in their name?
# - List the names of employees called Dianne or Diane.
# - List the products containing ship or boat in their product name.
# - List the products with a product code beginning with S700.
# - List the names of employees called Larry or Barry.
# - List the names of employees with non-alphabetic characters in their names.
# - List the vendors whose name ends in Diecast
#
# *Correlated subqueries*
#
# - Who reports to Mary Patterson?
# - Which payments in any month and year are more than twice the average for that month and year (i.e. compare all payments in Oct 2004 with the average payment for Oct 2004)? Order the results by the date of the payment. You will need to use the date functions.
# - Report for each product, the percentage value of its stock on hand as a percentage of the stock on hand for product line to which it belongs. Order the report by product line and percentage value within product line descending. Show percentages with two decimal places.
# - For orders containing more than two products, report those products that constitute more than 50% of the value of the order.

# %%
Customers = pd.read_csv('data/ClassicModels_Customers.csv', sep=';')

# %%
Customers.head(1)
# Out:
#    customerNumber       customerName contactLastName contactFirstName  \
# 0             103  Atelier graphique         Schmitt          Carine
#
#         phone    addressLine1 addressLine2    city state postalCode country  \
# 0  40.32.2555  54, rue Royale          NaN  Nantes   NaN      44000  France
#
#    salesRepEmployeeNumber  creditLimit  customerLocation
# 0                    1370      21000.0                 0

# %%
Employees = pd.read_csv('data/ClassicModels_Employees.csv', sep=';')

# %%
Employees.head(1)
# Out:
#    employeeNumber lastName firstName extension                         email  \
# 0            1002   Murphy     Diane     x5800  dmurphy@classicmodelcars.com
#
#    reportsTo   jobTitle  officeCode
# 0          0  President           1

# %%
Offices = pd.read_csv('data/ClassicModels_Offices.csv', sep=';')

# %%
Offices.head(1)
# Out:
#    officeCode           city            phone       addressLine1 addressLine2  \
# 0           1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
#
#   state country postalCode territory  officeLocation
# 0    CA     USA      94080       NaN               0

# %%
OrderDetails = pd.read_csv('data/ClassicModels_OrderDetails.csv', sep=';')

# %%
OrderDetails.head(1)
# Out:
#    orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0        10107    S10_1678               30      81.35                2

# %%
Orders = pd.read_csv('data/ClassicModels_Orders.csv', sep=';')

# %%
Orders.head(1)
# Out:
#    orderNumber            orderDate         requiredDate          shippedDate  \
# 0        10100  2003-01-06 00:00:00  2003-01-13 00:00:00  2003-01-10 00:00:00
#
#     status comments  customerNumber
# 0  Shipped      NaN             363

# %%
Payments = pd.read_csv('data/ClassicModels_Payments.csv', sep=';')

# %%
Payments.head(1)
# Out:
#   checkNumber          paymentDate   amount  customerNumber
# 0    AB661578  2004-07-28 00:00:00  9415.13             471

# %%
ProductLines = pd.read_csv('data/ClassicModels_ProductLines.csv', sep=';')

# %%
ProductLines.head(1)
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
#
#    htmlDescription  image
# 0              NaN    NaN

# %%
Products = pd.read_csv('data/ClassicModels_Products.csv', sep=';')

# %%
Products.head(1)
# Out:
#   productCode                            productName productScale  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper         1:10
#
#      productVendor                                 productDescription  \
# 0  Min Lin Diecast  This replica features working kickstand, front...
#
#    quantityInStock  buyPrice  MSRP  productLine
# 0             7933     48.81  95.7  Motorcycles

# %% [markdown]
# # Solutions

# %%
#Find products containing the name 'Ford'.
Products[Products.productName.str.contains('Ford')]
# Out:
#    productCode                       productName productScale  \
# 6     S12_1099                 1968 Ford Mustang         1:12
# 12    S12_3891                  1969 Ford Falcon         1:12
# 16    S18_1097            1940 Ford Pickup Truck         1:18
# 26    S18_2248                1911 Ford Town Car         1:18
# 28    S18_2325         1932 Model A Ford J-Coupe         1:18
# 29    S18_2432             1926 Ford Fire Engine         1:18
# 34    S18_2949       1913 Ford Model T Speedster         1:18
# 35    S18_2957                1934 Ford V8 Coupe         1:18
# 38    S18_3140                 1903 Ford Model A         1:18
# 44    S18_3482             1976 Ford Gran Torino         1:18
# 51    S18_4600                  1940s Ford truck         1:18
# 54    S18_4933             1957 Ford Thunderbird         1:18
# 71    S24_3151  1912 Ford Model T Delivery Wagon         1:24
# 76    S24_3816          1940 Ford Delivery Sedan         1:24
# 90    S32_4289          1928 Ford Phaeton Deluxe         1:32
#
#                productVendor  \
# 6      Autoart Studio Design
# 12       Second Gear Diecast
# 16       Studio M Art Models
# 26   Motor City Art Classics
# 28     Autoart Studio Design
# 29  Carousel DieCast Legends
# 34  Carousel DieCast Legends
# 35           Min Lin Diecast
# 38      Unimax Art Galleries
# 44      Gearbox Collectibles
# 51   Motor City Art Classics
# 54       Studio M Art Models
# 71           Min Lin Diecast
# 76  Carousel DieCast Legends
# 90  Highway 66 Mini Classics
#
#                                    productDescription  quantityInStock  \
# 6   Hood, doors and trunk all open to reveal highl...               68
# 12  Turnable front wheels; steering function; deta...             1049
# 16  This model features soft rubber tires, working...             2613
# 26  Features opening hood, opening doors, opening ...              540
# 28  This model features grille-mounted chrome horn...             9354
# 29  Gleaming red handsome appearance. Everything i...             2018
# 34  This 250 part reproduction includes moving han...             4189
# 35  Chrome Trim, Chrome Grille, Opening Hood, Open...             5649
# 38   Features opening trunk,  working steering system             3913
# 44  Highly detailed 1976 Ford 'Gran Torino' Starsk...             9127
# 51  This 1940s Ford Pick-Up truck is re-created in...             3128
# 54  This 1:18 scale precision die-cast replica, wi...             3209
# 71  This model features chrome trim and grille, op...             9173
# 76  Chrome Trim, Chrome Grille, Opening Hood, Open...             6621
# 90  This model features grille-mounted chrome horn...              136
#
#     buyPrice    MSRP       productLine
# 6      95.34  194.57      Classic Cars
# 12     83.05  173.02      Classic Cars
# 16     58.33  116.67  Trucks and Buses
# 26     33.30   60.54      Vintage Cars
# 28     58.48  127.13      Vintage Cars
# 29     24.92   60.77  Trucks and Buses
# 34     60.78  101.31      Vintage Cars
# 35     34.35   62.46      Vintage Cars
# 38     68.30  136.59      Vintage Cars
# 44     73.49  146.99      Classic Cars
# 51     84.76  121.08  Trucks and Buses
# 54     34.21   71.27      Classic Cars
# 71     46.91   88.51      Vintage Cars
# 76     48.64   83.86      Vintage Cars
# 90     33.02   68.79      Vintage Cars

# %%
# List products ending in 'ship'.
Products[Products.productName.str.endswith('ship')]
# Out:
# Empty DataFrame
# Columns: [productCode, productName, productScale, productVendor, productDescription, quantityInStock, buyPrice, MSRP, productLine]
# Index: []

# %%
#Report the number of customers in Denmark, Norway, and Sweden.
len(Customers.set_index('country').loc[['Denmark', 'Norway', 'Sweden']])
# Out:
# 5

# %%
#What are the products with a product code in the range S700_1000 to S700_1499?
Products.set_index('productCode').loc['S700_1000':'S700_1499']
# Out:
#                        productName productScale          productVendor  \
# productCode
# S700_1138    The Schooner Bluenose        1:700  Autoart Studio Design
#
#                                             productDescription  \
# productCode
# S700_1138    All wood with canvas sails. Measures 31 1/2 in...
#
#              quantityInStock  buyPrice   MSRP productLine
# productCode
# S700_1138               1897      34.0  66.67       Ships

# %%
#Which customers have a digit in their name?
Customers[Customers.customerName.str.contains('\d')]
# Out:
#     customerNumber       customerName contactLastName contactFirstName  \
# 35             205  Toys4GrownUps.com           Young            Julie
# 84             362  Gifts4AllAges.com         Yoshido             Juri
#
#          phone        addressLine1 addressLine2      city state postalCode  \
# 35  6265557265  78934 Hillside Dr.          NaN  Pasadena    CA      90003
# 84  6175559555  8616 Spinnaker Dr.          NaN    Boston    MA      51003
#
#    country  salesRepEmployeeNumber  creditLimit  customerLocation
# 35     USA                    1166      90700.0                 0
# 84     USA                    1216      41900.0                 0

# %%
#List the names of employees called Dianne or Diane.
Employees.loc[Employees.firstName.str.match('Dianne|Diane'), ['firstName', 'lastName']]
# Out:
#   firstName lastName
# 0     Diane   Murphy

# %%
# List the products containing ship or boat in their product name.
Products[Products.productName.str.contains('ship|boat')]
# Out:
# Empty DataFrame
# Columns: [productCode, productName, productScale, productVendor, productDescription, quantityInStock, buyPrice, MSRP, productLine]
# Index: []

# %%
# List the products with a product code beginning with S700.
Products[Products.productCode.str.startswith('S700')]
# Out:
#     productCode                     productName productScale  \
# 96    S700_1138           The Schooner Bluenose        1:700
# 97    S700_1691     American Airlines: B767-300        1:700
# 98    S700_1938                   The Mayflower        1:700
# 99    S700_2047                      HMS Bounty        1:700
# 100   S700_2466  America West Airlines B757-200        1:700
# 101   S700_2610       The USS Constitution Ship        1:700
# 102   S700_2824                 1982 Camaro Z28         1:18
# 103   S700_2834                   ATA: B757-300        1:700
# 104   S700_3167              F/A 18 Hornet 1/72         1:72
# 105   S700_3505                     The Titanic        1:700
# 106   S700_3962                  The Queen Mary        1:700
# 107   S700_4002       American Airlines: MD-11S        1:700
#
#                  productVendor  \
# 96       Autoart Studio Design
# 97             Min Lin Diecast
# 98         Studio M Art Models
# 99        Unimax Art Galleries
# 100    Motor City Art Classics
# 101          Red Start Diecast
# 102   Carousel DieCast Legends
# 103   Highway 66 Mini Classics
# 104    Motor City Art Classics
# 105   Carousel DieCast Legends
# 106  Welly Diecast Productions
# 107        Second Gear Diecast
#
#                                     productDescription  quantityInStock  \
# 96   All wood with canvas sails. Measures 31 1/2 in...             1897
# 97   Exact replia with official logos and insignias...             5841
# 98   Measures 31 1/2 inches Long x 25 1/2 inches Hi...              737
# 99   Measures 30 inches Long x 27 1/2 inches High x...             3501
# 100  Official logos and insignias. Working steering...             9653
# 101  All wood with canvas sails. Measures 31 1/2 in...             7083
# 102  Features include opening and closing doors. Co...             6934
# 103  Exact replia with official logos and insignias...             7106
# 104  10 inches Wingspan with retractable landing ge...              551
# 105  Completed model measures 19 1/2 inches long, 9...             1956
# 106  Exact replica. Wood and Metal. Many extras inc...             5088
# 107  Polished finish. Exact replia with official lo...             8820
#
#      buyPrice    MSRP   productLine
# 96      34.00   66.67         Ships
# 97      51.15   91.34        Planes
# 98      43.30   86.61         Ships
# 99      39.83   90.52         Ships
# 100     68.80   99.72        Planes
# 101     33.97   72.28         Ships
# 102     46.53  101.15  Classic Cars
# 103     59.33  118.65        Planes
# 104     54.40   80.00        Planes
# 105     51.09  100.17         Ships
# 106     53.63   99.31         Ships
# 107     36.27   74.03        Planes

# %%
# List the names of employees called Larry or Barry.
Employees.loc[Employees.firstName.str.match('[HB]arry'), ['firstName', 'lastName']]
# Out:
#    firstName lastName
# 16     Barry    Jones

# %%
#List the names of employees with non-alphabetic characters in their names.
Employees.loc[Employees.firstName.str.contains('\W') | Employees.lastName.str.contains('\W'), ['firstName', 'lastName']]
# Out:
#    firstName lastName
# 10  Foon Yue    Tseng

# %%
# List the vendors whose name ends in Diecast
set(Products.loc[Products.productVendor.str.contains('Diecast'), 'productVendor'])
# Out:
# {'Min Lin Diecast',
#  'Red Start Diecast',
#  'Second Gear Diecast',
#  'Welly Diecast Productions'}

# %%
# Who reports to Mary Patterson?
# sol-1 using joins
j = Employees.set_index('employeeNumber').join(Employees.set_index('reportsTo'), lsuffix='_boss')
j.loc[(j.firstName_boss == 'Mary') & (j.lastName_boss == 'Patterson'), ['firstName', 'lastName']]
# Out:
#      firstName   lastName
# 1056   William  Patterson
# 1056    Gerard     Bondur
# 1056   Anthony        Bow
# 1056      Mami      Nishi

# %%
# sol-2, two step, get Mary Patterson number, then filter
boss_number = Employees.loc[(Employees.firstName == 'Mary') & (Employees.lastName == 'Patterson'), 'employeeNumber'].iloc[0]
Employees[Employees.reportsTo == boss_number]
# Out:
#     employeeNumber   lastName firstName extension  \
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 20            1621      Nishi      Mami      x101
#
#                               email  reportsTo              jobTitle  \
# 3   wpatterson@classicmodelcars.com       1056  Sales Manager (APAC)
# 4      gbondur@classicmodelcars.com       1056   Sale Manager (EMEA)
# 5         abow@classicmodelcars.com       1056    Sales Manager (NA)
# 20      mnishi@classicmodelcars.com       1056             Sales Rep
#
#     officeCode
# 3            6
# 4            4
# 5            1
# 20           5

# %%
# Which payments in any month and year are more than 
#twice the average for that month and year 
#(i.e. compare all payments in Oct 2004 with the average payment for Oct 2004)? Order the results by the date of the payment. You will need to use the date functions.


Payments['month_year'] = Payments.paymentDate.str[:7]
payment_average = Payments.groupby('month_year')['amount'].mean()
j = Payments.set_index('month_year').join(payment_average, rsuffix='_avg')
j[j.amount > 2 * j.amount_avg]
# Out:
#            checkNumber          paymentDate     amount  customerNumber  \
# month_year
# 2003-04       BI507030  2003-04-22 00:00:00   44380.15             148
# 2003-08       KI131716  2003-08-15 00:00:00  111654.40             124
# 2003-10       JN355280  2003-10-26 00:00:00   49539.37             141
# 2003-11        DJ15149  2003-11-03 00:00:00   85559.12             321
# 2003-12       GN228846  2003-12-03 00:00:00   85024.46             167
# 2003-12       KM172879  2003-12-26 00:00:00  105743.00             148
# 2004-02       PB951268  2004-02-13 00:00:00   36070.47             475
# 2004-03       NQ865547  2004-03-15 00:00:00   80375.24             239
# 2004-08       BG255406  2004-08-28 00:00:00   85410.87             124
# 2004-10        HE84936  2004-10-22 00:00:00   53116.99             256
# 2004-12        ID10962  2004-12-31 00:00:00  116208.40             141
# 2004-12       MA765515  2004-12-15 00:00:00   82261.22             114
# 2005-03       AE215433  2005-03-05 00:00:00  101244.59             124
# 2005-03       JE105477  2005-03-18 00:00:00  120166.58             141
# 2005-04        ET64396  2005-04-16 00:00:00   83598.04             124
# 2005-05       AL493079  2005-05-23 00:00:00   75020.13             323
#
#               amount_avg
# month_year
# 2003-04     19473.417143
# 2003-08     41034.143333
# 2003-10     24373.689231
# 2003-11     36541.720000
# 2003-12     41331.882000
# 2003-12     41331.882000
# 2004-02     17775.335000
# 2004-03     36782.110000
# 2004-08     34372.209091
# 2004-10     26443.347143
# 2004-12     35621.113913
# 2004-12     35621.113913
# 2005-03     48158.511250
# 2005-03     48158.511250
# 2005-04     36779.544000
# 2005-05     30249.881111

# %%
#TODO
#Report for each product, the percentage value of its stock on hand as a percentage of the stock on hand for product line to which it belongs. Order the report by product line and percentage value within product line descending. Show percentages with two decimal places.
#For orders containing more than two products, report those products that constitute more than 50% of the value of the order.
