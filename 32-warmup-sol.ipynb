# %%
import pandas as pd
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
data = pd.read_csv("data/titanic.csv")

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Provide a visualization to communicate the analyses below
#
# ## Use Altair transformation and aggragation capabilities, rather than Pandas

# %% [markdown]
# ## How did survival depend on sex and class?

# %%
data.groupby(['sex', 'class']).survived.sum().unstack('sex')
# Out:
# sex     female  male
# class
# First       91    45
# Second      70    17
# Third       72    47

# %%
alt.Chart(data).mark_bar().encode(
    x='class',
    y='sex',
    color='count()')

# %%
alt.Chart(data).mark_bar().transform_aggregate(
    passengers='count()',
    groupby=['class', 'sex']).encode(
    x='class',
    y='sex',
    color='passengers:Q')

# %% [markdown]
# ## What was the distribution of passengers in decks

# %%
data.groupby(['deck']).age.count()
# Out:
# deck
# A    12
# B    45
# C    51
# D    31
# E    30
# F    11
# G     4
# Name: age, dtype: int64

# %%
alt.Chart(data).mark_bar().transform_filter(
    'datum.deck != null'
    ).encode(
    x='deck',
    y='count()')

# %% [markdown]
# ## Does deck correlate with class?

# %%
data.groupby(['deck', 'class']).age.count().unstack('class').fillna(0)
# Out:
# class  First  Second  Third
# deck
# A       12.0     0.0    0.0
# B       45.0     0.0    0.0
# C       51.0     0.0    0.0
# D       27.0     4.0    0.0
# E       24.0     3.0    3.0
# F        0.0     8.0    3.0
# G        0.0     0.0    4.0

# %%
alt.Chart(data).mark_bar().transform_filter(
    'datum.deck != null'
).transform_aggregate(
passengers='count()', groupby=['deck', 'class']).encode(
x='deck',
y='class',
color='passengers:Q')

# %%
alt.Chart(data).mark_bar().transform_aggregate(
passengers='count()', groupby=['deck', 'class']).transform_filter(
    'datum.deck != null'
).encode(
x='deck',
y='class',
color='passengers:Q')

# %% [markdown]
# ## How did survival depend on deck?

# %%
data.groupby(['deck']).survived.mean()
# Out:
# deck
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# Name: survived, dtype: float64

# %%
alt.Chart(data).mark_bar().transform_filter(
    'datum.deck != null'
).encode(
    x='deck',
    y='average(survived)')

# %%
alt.Chart(data).mark_bar().transform_filter(
    'datum.deck != null'
).transform_aggregate(
    survival='average(survived)',
    groupby=['deck']
).encode(
    x='deck',
    y='survival:Q')
