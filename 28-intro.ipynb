# %%
# install beautifulsoup for the first time if not there
#!conda install BeautifulSoup4
#!pip install BeautifulSoup4

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup

# %%
html="""<html>
    <head>
        <title>
            This is an example page
        </title>
    </head>
    <body>
        Here is the content of the page
        <p>
            One paragraph
        </p>
        <li> one </li>
        <li> two </li>
        <table>
            <tr>
                <td>col 1</td>
                <td>col 2</td>
            </tr>
            <tr>
                <td>val 1</td>
                <td>val 2</td>
            </tr>
        </table>
        End of body
    </body>
</html>"""

# %%
root = ET.fromstring(html)

# %%
for element in root.iter('td'):
    print(element.text)
# Out:
# col 1
# col 2
# val 1
# val 2

# %%
soup = BeautifulSoup(html, 'html')

# %%
for element in soup.find_all('td'):
    print(element.text)
# Out:
# col 1
# col 2
# val 1
# val 2

# %%
def print_html_tree(tag,level = 0):
    print('\t'*level + tag.name)
    for child in tag.findChildren():
        print_html_tree(child, level+1)

# %%
print_html_tree(soup.currentTag)
# Out:
# [document]
# 	html
# 		head
# 			title
# 		title
# 		body
# 			p
# 			li
# 			li
# 			table
# 				tr
# 					td
# 					td
# 				td
# 				td
# 				tr
# 					td
# 					td
# 				td
# 				td
# 			tr
# 				td
# 				td
# 			td
# 			td
# 			tr
# 				td
# 				td
# 			td
# 			td
# 		p
# 		li
# 		li
# 		table
# 			tr
# 				td
# 				td
# 			td
# 			td
# 			tr
# 				td
# 				td
# 			td
# 			td
# 		tr
# 			td
# 			td
# 		td
# 		td
# 		tr
# 			td
# 			td
# 		td
# 		td
# 	head
# 		title
# 	title
# 	body
# 		p
# 		li
# 		li
# 		table
# 			tr
# 				td
# 				td
# 			td
# 			td
# 			tr
# 				td
# 				td
# 			td
# 			td
# 		tr
# 			td
# 			td
# 		td
# 		td
# 		tr
# 			td
# 			td
# 		td
# 		td
# 	p
# 	li
# 	li
# 	table
# 		tr
# 			td
# 			td
# 		td
# 		td
# 		tr
# 			td
# 			td
# 		td
# 		td
# 	tr
# 		td
# 		td
# 	td
# 	td
# 	tr
# 		td
# 		td
# 	td
# 	td

# %% [markdown]
# Extract names and titles of [MIS Faulty at UGA](https://www.terry.uga.edu/directory/mis/)
#
# How many assistant professors are there?

# %%
r = requests.get("https://www.terry.uga.edu/directory/mis")

# %%
r.status_code
# Out:
# 200

# %%
html = r.text

# %%
type(html)
# Out:
# str

# %%
root = ET.fromstring(html)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/hanisaf/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-27-c6473bbe8570>", line 1, in <module>
#     root = ET.fromstring(html)
#
#   File "/Users/hanisaf/anaconda3/lib/python3.7/xml/etree/ElementTree.py", line 1315, in XML
#     parser.feed(text)
#
#   File "<string>", line unknown
# ParseError: mismatched tag: line 48, column 5

# %%
soup = BeautifulSoup(html, 'html')

# %%
names = soup.find_all('td', id="name")

# %%
titles = soup.find_all('td', id="title")

# %%
names[0].text
# Out:
# 'Becky Curry'

# %%
len(names) == len(titles)
# Out:
# True

# %%
# assemble the data
res = []
for i in range(len(names)):
    entry = {'Name': names[i].text.strip(), 'Title': titles[i].text.strip()}
    res.append(entry)

# %%
len(res)
# Out:
# 38

# %%
data = pd.DataFrame(res)

# %%
data.head()
# Out:
#                 Name                        Title
# 0        Becky Curry  Administrative Associate II
# 1   Jacob H. Steffen             Doctoral Student
# 2  Hugh James Watson          Part-Time Professor
# 3        Abdul Sesay          Assistant Professor
# 4      Mark W. Huber              Senior Lecturer

# %%
sum(data.Title == 'Assistant Professor')
# Out:
# 7
